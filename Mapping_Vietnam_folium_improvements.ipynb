# %% [markdown]
# # Vietnam Interactive Map 2
# Date: March 2023
# Author: Kathleen Shalini Rome
# Organisation: UNSW

# %%
# If you’re working in a Jupyter notebook be sure to run the following “magic” command to render plots properly:
# %matplotlib inline

# %%
import geoplot as gplt
import geopandas as gpd
import geoplot.crs as gcrs
import pandas as pd
import imageio
import pathlib
import matplotlib.pyplot as plt
import mapclassify as mc
import numpy as n
# Out:
# c:\Users\sy6sh\Anaconda3\envs\Honours_2022\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Loading shapefile of Vietnam commune
# Coordinate WGS84
# Opening files from different folder: https://stackoverflow.com/questions/35384358/how-to-open-my-files-in-data-folder-with-pandas-using-relative-path
vn_commune = gpd.read_file("Data_Boundaries/Admin3_commune_Vietnam/VNM_adm3.shp") 
# Source of VN files: https://data.humdata.org/dataset/cod-ab-vnm
# vn_commune
# I assume Name 1 is province, name 2 is district and name 3 is commune / ward/ town. 
# Renaming the columns
vn_commune = vn_commune.rename({'NAME_1': 'Province', 'NAME_2': 'District','NAME_3':'Commune/Town'}, axis=1)

# Getting the mekong delta communes, province, districts.
list_mk_prov_vn = ['Cần Thơ', 'Long An', 'Bến Tre', 'Tiền Giang', 'Vĩnh Long', 'Trà Vinh', 'Hậu Giang', 'Đồng Tháp', 'Sóc Trăng', 'An Giang', 'Bạc Liêu', 'Kiên Giang', 'Cà Mau']
# Select rows where column value is in List of Values - Source: https://www.statology.org/pandas-select-rows-based-on-column-values/
mk_commune = vn_commune.loc[vn_commune['Province'].isin(list_mk_prov_vn)]
mk_commune
# Out:
#        ID_0  ISO   NAME_0  ID_1   Province  ID_2   District   ID_3  \
# 222     250  VNM  Vietnam     3  Đồng Tháp    19   Cao Lãnh    223
# 223     250  VNM  Vietnam     3  Đồng Tháp    19   Cao Lãnh    224
# 224     250  VNM  Vietnam     3  Đồng Tháp    19   Cao Lãnh    225
# 225     250  VNM  Vietnam     3  Đồng Tháp    19   Cao Lãnh    226
# 226     250  VNM  Vietnam     3  Đồng Tháp    19   Cao Lãnh    227
# ...     ...  ...      ...   ...        ...   ...        ...    ...
# 10476   250  VNM  Vietnam    61  Vĩnh Long   659  Vĩnh Long  10477
# 10477   250  VNM  Vietnam    61  Vĩnh Long   659  Vĩnh Long  10478
# 10478   250  VNM  Vietnam    61  Vĩnh Long   659  Vĩnh Long  10479
# 10479   250  VNM  Vietnam    61  Vĩnh Long   659  Vĩnh Long  10480
# 10480   250  VNM  Vietnam    61  Vĩnh Long   659  Vĩnh Long  10481
#
#           Commune/Town  CCN_3 CCA_3   TYPE_3 ENGTYPE_3 NL_NAME_3 VARNAME_3  \
# 222            An Bình      0  None  Commune   Commune      None      None
# 223             Ba Sao      0  None  Commune   Commune      None      None
# 224      Bình Hàng Tây      0  None  Commune   Commune      None      None
# 225    Bình Hàng Trung      0  None  Commune   Commune      None      None
# 226         Bình Thạnh      0  None  Commune   Commune      None      None
# ...                ...    ...   ...      ...       ...       ...       ...
# 10476                9      0  None     Ward      Ward      None      None
# 10477          Tân Hội      0  None  Commune   Commune      None      None
# 10478          Tân Hòa      0  None  Commune   Commune      None      None
# 10479         Tân Ngãi      0  None  Commune   Commune      None      None
# 10480        Trường An      0  None  Commune   Commune      None      None
#
#                                                 geometry
# 222    POLYGON ((105.67486 10.44355, 105.67468 10.443...
# 223    POLYGON ((105.69276 10.50856, 105.69304 10.510...
# 224    POLYGON ((105.76463 10.35540, 105.76331 10.356...
# 225    POLYGON ((105.77689 10.41451, 105.77640 10.412...
# 226    POLYGON ((105.81646 10.32235, 105.81696 10.322...
# ...                                                  ...
# 10476  POLYGON ((105.95335 10.24382, 105.95323 10.243...
# 10477  POLYGON ((105.90015 10.24484, 105.89861 10.245...
# 10478  POLYGON ((105.91867 10.23340, 105.91857 10.232...
# 10479  POLYGON ((105.92652 10.24143, 105.92640 10.240...
# 10480  POLYGON ((105.94260 10.27176, 105.94310 10.271...
#
# [1532 rows x 16 columns]

# %%
# Loading database
#vn_database_loc = pd.read_csv('Database_test_encoded_utf_16_CSVutf8.csv', encoding='UTF-16LE', error_bad_lines=False)
vn_database_loc = pd.read_csv('Database_test_encoded_utf_16_CSVutf8.csv')
# Okay so I saved my xlsx file as a unicode text then opened it in notepad and then saved as a UTF16LE encoding and as a csv, then I opened it in csv and resaved in CSV utf8 encoding.
vn_database_loc = vn_database_loc.rename({'Commune': 'Commune/Town'}, axis=1)
vn_database_loc
# Out:
#     Start Month Start Year       End Month End Year  \
# 0          June       2013         October     2017
# 1           NaN       2014       December      2017
# 2   Rice season       2015           April     2019
# 3   Rice season       2015           April     2019
# 4       October       2018       December      2018
# 5       October       2018       December      2018
# 6      December       2013         October     2019
# 7          June       2018       December      2018
# 8           NaN        NaN             NaN      NaN
# 9           NaN        NaN             NaN      NaN
# 10          NaN        NaN             NaN      NaN
# 11          NaN        NaN             NaN      NaN
# 12          NaN        NaN             NaN      NaN
# 13          NaN        NaN             NaN      NaN
# 14          NaN       2013       September     2020
# 15          NaN       2013       September     2020
# 16          NaN       2013       September     2020
# 17          NaN       2013       September     2020
# 18          NaN       2013       September     2020
# 19          NaN          ?            July        ?
# 20          NaN       2017          August     2017
# 21          NaN          ?         October        ?
# 22         June       2017        November     2017
# 23      October       2014  ? Could be Feb     2015
# 24      October       2014  ? Could be Feb     2015
# 25      October       2014  ? Could be Feb     2015
# 26      October       2014  ? Could be Feb     2015
# 27      October       2014  ? Could be Feb     2015
# 28          NaN       2011             NaN     2013
# 29       Summer       2012          Autumn     2013
# 30       Summer       2012          Autumn     2014
# 31       Summer       2014          Autumn     2014
# 32       Summer       2013          Autumn     2013
#
#                                               Project  \
# 0   To better understand the key components of the...
# 1   Test the influence of key factors that will af...
# 2   Quantify the improvement to rice production by...
# 3   Quantify the improvement to rice production by...
# 4   Quantify the fertiliser replacement value of s...
# 5   Quantify the fertiliser replacement value of s...
# 6   Train staff in laboratory and field research t...
# 7   Determine nutrient (carbon, nitrogen, phosphor...
# 8                     Additional Socio-Economic Study
# 9                     Additional Socio-Economic Study
# 10                    Additional Socio-Economic Study
# 11                    Additional Socio-Economic Study
# 12  A second study, indirectly related to the proj...
# 13  A second study, indirectly related to the proj...
# 14  Improving the sustainability of rice-shrimp fa...
# 15  Improving the sustainability of rice-shrimp fa...
# 16  Improving the sustainability of rice-shrimp fa...
# 17  Improving the sustainability of rice-shrimp fa...
# 18  Improving the sustainability of rice-shrimp fa...
# 19                                BBN Farmer Workshop
# 20                                BBN Farmer Workshop
# 21                                    Annual Meetings
# 22                             Dissemination workshop
# 23  Adaptation of Rice-Shrimp Farming in the Mekon...
# 24  Adaptation of Rice-Shrimp Farming in the Mekon...
# 25  Adaptation of Rice-Shrimp Farming in the Mekon...
# 26  Adaptation of Rice-Shrimp Farming in the Mekon...
# 27  Adaptation of Rice-Shrimp Farming in the Mekon...
# 28  CLUES: Climate change affecting land use in th...
# 29  CLUES: Climate change affecting land use in th...
# 30  CLUES: Climate change affecting land use in th...
# 31  CLUES: Climate change affecting land use in th...
# 32  CLUES: Climate change affecting land use in th...
#
#                       Organisation  \
# 0                             UNSW
# 1                             UNSW
# 2                             UNSW
# 3                             UNSW
# 4                             UNSW
# 5                             UNSW
# 6                             UNSW
# 7                             UNSW
# 8                             UNSW
# 9                             UNSW
# 10                            UNSW
# 11                            UNSW
# 12                            UNSW
# 13                            UNSW
# 14                            UNSW
# 15                            UNSW
# 16                            UNSW
# 17                            UNSW
# 18                            UNSW
# 19                            UNSW
# 20                            UNSW
# 21                            UNSW
# 22                            UNSW
# 23  USAID, Mekong ARCC, ADMI, VNRC
# 24  USAID, Mekong ARCC, ADMI, VNRC
# 25  USAID, Mekong ARCC, ADMI, VNRC
# 26  USAID, Mekong ARCC, ADMI, VNRC
# 27  USAID, Mekong ARCC, ADMI, VNRC
# 28                           ACIAR
# 29                           ACIAR
# 30                           ACIAR
# 31                           ACIAR
# 32                           ACIAR
#
#                                           Description  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Presentation of initial results and collection...
# 20  Presentation of initial results and collection...
# 21  Presenting project findings, field visit, plan...
# 22  Extension workshop: inform provincial official...
# 23  The project implemented pilot rice-shrimp farm...
# 24  The project implemented pilot rice-shrimp farm...
# 25  The project implemented pilot rice-shrimp farm...
# 26  The project implemented pilot rice-shrimp farm...
# 27  The project implemented pilot rice-shrimp farm...
# 28  The CLUES project aimed at improving the adapt...
# 29  The CLUES project aimed at improving the adapt...
# 30  The CLUES project aimed at improving the adapt...
# 31  The CLUES project aimed at improving the adapt...
# 32  The CLUES project aimed at improving the adapt...
#
#                       Theme  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23  Adaptation initivatives
# 24  Adaptation initivatives
# 25  Adaptation initivatives
# 26  Adaptation initivatives
# 27  Adaptation initivatives
# 28                      NaN
# 29                      NaN
# 30                      NaN
# 31                      NaN
# 32                      NaN
#
#                                         Speific Theme  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  Salt-tolerant rice and sedge grass species; sh...
# 24  Salt-tolerant rice and sedge grass species; sh...
# 25  Salt-tolerant rice and sedge grass species; sh...
# 26  Salt-tolerant rice and sedge grass species; sh...
# 27  Salt-tolerant rice and sedge grass species; sh...
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
#
#    Training workshop / Research  \
# 0                      Research
# 1                      Research
# 2                      Research
# 3                      Research
# 4                      Research
# 5                      Research
# 6                      Research
# 7                      Research
# 8                      Research
# 9                      Research
# 10                     Research
# 11                     Research
# 12                     Research
# 13                     Research
# 14                     Research
# 15                     Research
# 16                     Research
# 17                     Research
# 18                     Research
# 19                     Workshop
# 20                     Workshop
# 21                 Presentation
# 22                     Workshop
# 23                     Research
# 24                     Research
# 25                     Research
# 26                     Research
# 27                     Research
# 28                     Research
# 29                     Research
# 30                     Research
# 31                     Research
# 32                     Training
#
#                                        Paper Location   District    Province  \
# 0                                                 NaN        NaN         NaN
# 1                                              Hao My   Cái Nước      Cà Mau
# 2                                              Hoa My   Cái Nước      Cà Mau
# 3                                            Tan Bang  Thới Bình      Cà Mau
# 4                                             Hoa My    Cái Nước      Cà Mau
# 5                                            Tan Bang  Thới Bình      Cà Mau
# 6                                                 NaN        NaN         NaN
# 7                                              Hoa My   Cái Nước      Cà Mau
# 8                               (1) Hoa Tu 1 commune    Mỹ Xuyên   Sóc Trăng
# 9                            (2) Phong Thanh commune     Giá Rai    Bạc Liêu
# 10                              (3) Tan bang commune   Thới Bình      Cà Mau
# 11                             (4) Tay Yen A commune     An Biên  Kiên Giang
# 12                                           Tan Bang  Thới Bình      Cà Mau
# 13                                             Hoa My   Cái Nước      Cà Mau
# 14                                   Tan Bang Commune  Thới Bình      Cà Mau
# 15                              (1) Hoa Tu 1 commune    Mỹ Xuyên   Sóc Trăng
# 16                           (2) Phong Thanh commune     Giá Rai    Bạc Liêu
# 17                              (3) Tan bang commune   Thới Bình      Cà Mau
# 18                             (4) Tay Yen A commune     An Biên  Kiên Giang
# 19                                                NaN        NaN     Cần Thơ
# 20                                                NaN        NaN      Cà Mau
# 21                                                NaN        NaN         NaN
# 22                                                NaN        NaN      Ca Mau
# 23                                                NaN   An Minh   Kiên Giang
# 24                                                NaN        NaN      Cà Mau
# 25                                                NaN        NaN    Bạc Liêu
# 26                                                NaN        NaN   Sóc Trăng
# 27                                                NaN        NaN    Trà Vinh
# 28                                                NaN        NaN    An Giang
# 29                                                NaN    Vị Thủy   Hậu Giang
# 30                                                NaN   Thới Lai     Cần Thơ
# 31                                                NaN        NaN    Bạc Liêu
# 32  CLRRI, Thới Thạnh, Thới Lai, Cần Thơ 94000, Vi...   Thới Lai     Cần Thơ
#
#    Commune/Town                                             Source  \
# 0           NaN  https://www.aciar.gov.au/sites/default/files/2...
# 1        Hoà Mỹ  https://www.aciar.gov.au/sites/default/files/2...
# 2        Hoà Mỹ  https://www.aciar.gov.au/sites/default/files/2...
# 3      Tân Bằng  https://www.aciar.gov.au/sites/default/files/2...
# 4        Hoà Mỹ  https://www.aciar.gov.au/sites/default/files/2...
# 5      Tân Bằng  https://www.aciar.gov.au/sites/default/files/2...
# 6           NaN  https://www.aciar.gov.au/sites/default/files/2...
# 7        Hoà Mỹ  https://www.aciar.gov.au/sites/default/files/2...
# 8      Hòa Tú 1  https://www.aciar.gov.au/sites/default/files/2...
# 9   Phong Thạnh  https://www.aciar.gov.au/sites/default/files/2...
# 10     Tân Bằng  https://www.aciar.gov.au/sites/default/files/2...
# 11      Tây Yên  https://www.aciar.gov.au/sites/default/files/2...
# 12     Tân Bằng  https://www.aciar.gov.au/sites/default/files/2...
# 13       Hoà Mỹ  https://www.aciar.gov.au/sites/default/files/2...
# 14     Tân Bằng     https://www.aciar.gov.au/project/smcn-2010-083
# 15     Hòa Tú 1     https://www.aciar.gov.au/project/smcn-2010-084
# 16  Phong Thạnh     https://www.aciar.gov.au/project/smcn-2010-085
# 17     Tân Bằng     https://www.aciar.gov.au/project/smcn-2010-086
# 18    Tây Yên A     https://www.aciar.gov.au/project/smcn-2010-087
# 19          NaN     https://www.aciar.gov.au/project/smcn-2010-088
# 20          NaN     https://www.aciar.gov.au/project/smcn-2010-089
# 21          NaN     https://www.aciar.gov.au/project/smcn-2010-090
# 22          NaN     https://www.aciar.gov.au/project/smcn-2010-091
# 23    Thuận Hòa        https://pdf.usaid.gov/pdf_docs/PA00M3XG.pdf
# 24          NaN        https://pdf.usaid.gov/pdf_docs/PA00M3XG.pdf
# 25          NaN        https://pdf.usaid.gov/pdf_docs/PA00M3XG.pdf
# 26          NaN        https://pdf.usaid.gov/pdf_docs/PA00M3XG.pdf
# 27          NaN        https://pdf.usaid.gov/pdf_docs/PA00M3XG.pdf
# 28    Lang Giai  https://www.aciar.gov.au/sites/default/files/2...
# 29      Vị Đông  https://www.aciar.gov.au/sites/default/files/2...
# 30     Thới Tân  https://www.aciar.gov.au/sites/default/files/2...
# 31      Tà Đảnh  https://www.aciar.gov.au/sites/default/files/2...
# 32   Thới Thạnh  https://www.aciar.gov.au/sites/default/files/2...
#
#                                               Comment
# 0                                                 NaN
# 1   Monitoring salinity in soil pore solution and ...
# 2                                                 NaN
# 3                                                 NaN
# 4   Dates reflect incorporation of additional trai...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                           What provinces are they?
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  Would you include this as locations instead? P...
# 23  Report is on computer. Secondary source: https...
# 24  These are mentioned -  "These pilot initiative...
# 25  These are mentioned -  "These pilot initiative...
# 26  These are mentioned -  "These pilot initiative...
# 27  These are mentioned -  "These pilot initiative...
# 28  Location based on Table 5. Some 64 publication...
# 29  Location based on Table 5. Some 64 publication...
# 30  Location based on Table 5. Some 64 publication...
# 31  Location based on Table 5. Some 64 publication...
# 32  Location based on Table 5. Some 64 publication...

# %%
# Getting polygons
# https://geopandas.org/en/stable/docs/user_guide/mergingdata.html I used this to get the merge formula and this link https://stackoverflow.com/questions/17978133/python-pandas-merge-only-certain-columns to get only specific columns
geocoded_database = vn_database_loc.merge(mk_commune[['Commune/Town','geometry']], on='Commune/Town')
geocoded_database.to_csv('geocoded_database.csv')
geocoded_database.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 0 to 17
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Start Month                   10 non-null     object
#  1   Start Year                    14 non-null     object
#  2   End Month                     14 non-null     object
#  3   End Year                      14 non-null     object
#  4   Project                       18 non-null     object
#  5   Organisation                  18 non-null     object
#  6   Description                   4 non-null      object
#  7   Theme                         1 non-null      object
#  8   Speific Theme                 1 non-null      object
#  9   Training workshop / Research  18 non-null     object
#  10  Paper Location                16 non-null     object
#  11  District                      17 non-null     object
#  12  Province                      18 non-null     object
#  13  Commune/Town                  18 non-null     object
#  14  Source                        18 non-null     object
#  15  Comment                       8 non-null      object
#  16  geometry                      18 non-null     geometry
# dtypes: geometry(1), object(16)
# memory usage: 2.5+ KB

# %%
#making pandas to geopandas
database_gdf = gpd.GeoDataFrame(geocoded_database)

# %%
database_gdf
# Out:
#     Start Month Start Year       End Month End Year  \
# 0           NaN       2014       December      2017
# 1           NaN       2014       December      2017
# 2   Rice season       2015           April     2019
# 3   Rice season       2015           April     2019
# 4       October       2018       December      2018
# 5       October       2018       December      2018
# 6          June       2018       December      2018
# 7          June       2018       December      2018
# 8           NaN        NaN             NaN      NaN
# 9           NaN        NaN             NaN      NaN
# 10          NaN        NaN             NaN      NaN
# 11          NaN       2013       September     2020
# 12          NaN        NaN             NaN      NaN
# 13          NaN       2013       September     2020
# 14      October       2014  ? Could be Feb     2015
# 15       Summer       2014          Autumn     2014
# 16       Summer       2013          Autumn     2013
# 17       Summer       2013          Autumn     2013
#
#                                               Project  \
# 0   Test the influence of key factors that will af...
# 1   Test the influence of key factors that will af...
# 2   Quantify the improvement to rice production by...
# 3   Quantify the improvement to rice production by...
# 4   Quantify the fertiliser replacement value of s...
# 5   Quantify the fertiliser replacement value of s...
# 6   Determine nutrient (carbon, nitrogen, phosphor...
# 7   Determine nutrient (carbon, nitrogen, phosphor...
# 8   A second study, indirectly related to the proj...
# 9   A second study, indirectly related to the proj...
# 10                    Additional Socio-Economic Study
# 11  Improving the sustainability of rice-shrimp fa...
# 12                    Additional Socio-Economic Study
# 13  Improving the sustainability of rice-shrimp fa...
# 14  Adaptation of Rice-Shrimp Farming in the Mekon...
# 15  CLUES: Climate change affecting land use in th...
# 16  CLUES: Climate change affecting land use in th...
# 17  CLUES: Climate change affecting land use in th...
#
#                       Organisation  \
# 0                             UNSW
# 1                             UNSW
# 2                             UNSW
# 3                             UNSW
# 4                             UNSW
# 5                             UNSW
# 6                             UNSW
# 7                             UNSW
# 8                             UNSW
# 9                             UNSW
# 10                            UNSW
# 11                            UNSW
# 12                            UNSW
# 13                            UNSW
# 14  USAID, Mekong ARCC, ADMI, VNRC
# 15                           ACIAR
# 16                           ACIAR
# 17                           ACIAR
#
#                                           Description  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  The project implemented pilot rice-shrimp farm...
# 15  The CLUES project aimed at improving the adapt...
# 16  The CLUES project aimed at improving the adapt...
# 17  The CLUES project aimed at improving the adapt...
#
#                       Theme  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14  Adaptation initivatives
# 15                      NaN
# 16                      NaN
# 17                      NaN
#
#                                         Speific Theme  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  Salt-tolerant rice and sedge grass species; sh...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
#
#    Training workshop / Research  \
# 0                      Research
# 1                      Research
# 2                      Research
# 3                      Research
# 4                      Research
# 5                      Research
# 6                      Research
# 7                      Research
# 8                      Research
# 9                      Research
# 10                     Research
# 11                     Research
# 12                     Research
# 13                     Research
# 14                     Research
# 15                     Research
# 16                     Training
# 17                     Training
#
#                                        Paper Location  District    Province  \
# 0                                              Hao My  Cái Nước      Cà Mau
# 1                                              Hao My  Cái Nước      Cà Mau
# 2                                              Hoa My  Cái Nước      Cà Mau
# 3                                              Hoa My  Cái Nước      Cà Mau
# 4                                             Hoa My   Cái Nước      Cà Mau
# 5                                             Hoa My   Cái Nước      Cà Mau
# 6                                              Hoa My  Cái Nước      Cà Mau
# 7                                              Hoa My  Cái Nước      Cà Mau
# 8                                              Hoa My  Cái Nước      Cà Mau
# 9                                              Hoa My  Cái Nước      Cà Mau
# 10                           (2) Phong Thanh commune    Giá Rai    Bạc Liêu
# 11                           (2) Phong Thanh commune    Giá Rai    Bạc Liêu
# 12                             (4) Tay Yen A commune    An Biên  Kiên Giang
# 13                             (4) Tay Yen A commune    An Biên  Kiên Giang
# 14                                                NaN  An Minh   Kiên Giang
# 15                                                NaN       NaN    Bạc Liêu
# 16  CLRRI, Thới Thạnh, Thới Lai, Cần Thơ 94000, Vi...  Thới Lai     Cần Thơ
# 17  CLRRI, Thới Thạnh, Thới Lai, Cần Thơ 94000, Vi...  Thới Lai     Cần Thơ
#
#    Commune/Town                                             Source  \
# 0        Hoà Mỹ  https://www.aciar.gov.au/sites/default/files/2...
# 1        Hoà Mỹ  https://www.aciar.gov.au/sites/default/files/2...
# 2        Hoà Mỹ  https://www.aciar.gov.au/sites/default/files/2...
# 3        Hoà Mỹ  https://www.aciar.gov.au/sites/default/files/2...
# 4        Hoà Mỹ  https://www.aciar.gov.au/sites/default/files/2...
# 5        Hoà Mỹ  https://www.aciar.gov.au/sites/default/files/2...
# 6        Hoà Mỹ  https://www.aciar.gov.au/sites/default/files/2...
# 7        Hoà Mỹ  https://www.aciar.gov.au/sites/default/files/2...
# 8        Hoà Mỹ  https://www.aciar.gov.au/sites/default/files/2...
# 9        Hoà Mỹ  https://www.aciar.gov.au/sites/default/files/2...
# 10  Phong Thạnh  https://www.aciar.gov.au/sites/default/files/2...
# 11  Phong Thạnh     https://www.aciar.gov.au/project/smcn-2010-085
# 12      Tây Yên  https://www.aciar.gov.au/sites/default/files/2...
# 13    Tây Yên A     https://www.aciar.gov.au/project/smcn-2010-087
# 14    Thuận Hòa        https://pdf.usaid.gov/pdf_docs/PA00M3XG.pdf
# 15      Tà Đảnh  https://www.aciar.gov.au/sites/default/files/2...
# 16   Thới Thạnh  https://www.aciar.gov.au/sites/default/files/2...
# 17   Thới Thạnh  https://www.aciar.gov.au/sites/default/files/2...
#
#                                               Comment  \
# 0   Monitoring salinity in soil pore solution and ...
# 1   Monitoring salinity in soil pore solution and ...
# 2                                                 NaN
# 3                                                 NaN
# 4   Dates reflect incorporation of additional trai...
# 5   Dates reflect incorporation of additional trai...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  Report is on computer. Secondary source: https...
# 15  Location based on Table 5. Some 64 publication...
# 16  Location based on Table 5. Some 64 publication...
# 17  Location based on Table 5. Some 64 publication...
#
#                                              geometry  \
# 0   POLYGON ((105.03860 9.00347, 105.04353 8.99474...
# 1   POLYGON ((105.65816 9.80294, 105.65744 9.80370...
# 2   POLYGON ((105.03860 9.00347, 105.04353 8.99474...
# 3   POLYGON ((105.65816 9.80294, 105.65744 9.80370...
# 4   POLYGON ((105.03860 9.00347, 105.04353 8.99474...
# 5   POLYGON ((105.65816 9.80294, 105.65744 9.80370...
# 6   POLYGON ((105.03860 9.00347, 105.04353 8.99474...
# 7   POLYGON ((105.65816 9.80294, 105.65744 9.80370...
# 8   POLYGON ((105.03860 9.00347, 105.04353 8.99474...
# 9   POLYGON ((105.65816 9.80294, 105.65744 9.80370...
# 10  POLYGON ((106.14709 9.83280, 106.14690 9.83262...
# 11  POLYGON ((106.14709 9.83280, 106.14690 9.83262...
# 12  POLYGON ((105.09789 9.90625, 105.09492 9.90548...
# 13  POLYGON ((105.11459 9.86361, 105.11301 9.86261...
# 14  POLYGON ((105.92314 9.70955, 105.92242 9.70896...
# 15  POLYGON ((105.05420 10.37236, 105.05364 10.372...
# 16  POLYGON ((106.40025 9.96576, 106.39942 9.96639...
# 17  POLYGON ((105.62748 10.09094, 105.62756 10.090...
#
#                       centroid
# 0    POINT (104.99617 9.00692)
# 1    POINT (105.69704 9.81557)
# 2    POINT (104.99617 9.00692)
# 3    POINT (105.69704 9.81557)
# 4    POINT (104.99617 9.00692)
# 5    POINT (105.69704 9.81557)
# 6    POINT (104.99617 9.00692)
# 7    POINT (105.69704 9.81557)
# 8    POINT (104.99617 9.00692)
# 9    POINT (105.69704 9.81557)
# 10   POINT (106.13340 9.84456)
# 11   POINT (106.13340 9.84456)
# 12   POINT (105.05670 9.91569)
# 13   POINT (105.08506 9.87336)
# 14   POINT (105.90495 9.68629)
# 15  POINT (105.08334 10.40495)
# 16   POINT (106.43261 9.96844)
# 17  POINT (105.59007 10.09866)

# %%
#Creating map
import folium

# %%
map = folium.Map(location =[10,105],tiles='OpenStreetMap',zoom_start = 7)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a35e06993178117b10e24efaabfb4f7e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a35e06993178117b10e24efaabfb4f7e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a35e06993178117b10e24efaabfb4f7e = L.map(
#                 &quot;map_a35e06993178117b10e24efaabfb4f7e&quot;,
#                 {
#                     center: [10.0, 105.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1927d6d98872c1ca8fbb00bf5dbacd28 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a35e06993178117b10e24efaabfb4f7e);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Loading shapefile of Vietnam provinces
vn_province = gpd.read_file("Data_Boundaries/vnm_adm_gov_20201027/vnm_admbnda_adm1_gov_20201027.shp")
# Source of VN files:https://data.humdata.org/dataset/cod-ab-vnm
vn_province.head()
# Loading shapefile of Vietnam district
vn_district = gpd.read_file("Data_Boundaries/vnm_adm_gov_20201027/vnm_admbnda_adm2_gov_20201027.shp")
# Source of VN files:https://data.humdata.org/dataset/cod-ab-vnm
vn_district.head()

# Reducing file size
list_mk_prov = ['Can Tho city', 'Long An', 'Ben Tre', 'Tien Giang', 'Vinh Long', 'Tra Vinh', 'Hau Giang', 'Dong Thap', 'Soc Trang', 'An Giang', 'Bac Lieu', 'Kien Giang', 'Ca Mau']
#Select rows where column is equal to specific value
#vn_province.loc[vn_province['ADM1_EN']== 'Can Tho city']
# Select rows where column value is in List of Values - Source: https://www.statology.org/pandas-select-rows-based-on-column-values/
mk_provinces = vn_province.loc[vn_province['ADM1_EN'].isin(list_mk_prov)]
#mk_provinces
# Reducing district to Mekong Delta Districts file
list_mk_prov = ['Can Tho city', 'Long An', 'Ben Tre', 'Tien Giang', 'Vinh Long', 'Tra Vinh', 'Hau Giang', 'Dong Thap', 'Soc Trang', 'An Giang', 'Bac Lieu', 'Kien Giang', 'Ca Mau']
# Select rows where column value is in List of Values - Source: https://www.statology.org/pandas-select-rows-based-on-column-values/
mk_district = vn_district.loc[vn_district['ADM1_EN'].isin(list_mk_prov)]
mk_district
# Out:
#      Shape_Leng  Shape_Area     ADM2_EN           ADM2_VI ADM2_PCODE ADM2_REF  \
# 1      0.778150    0.032598     An Bien     Huyện An Biên    VN81315     None
# 6      1.053450    0.048158     An Minh     Huyện An Minh    VN81317     None
# 8      0.694846    0.018661      An Phu      Huyện An Phú    VN80505     None
# 19     0.757167    0.029617      Ba Tri      Huyện Ba Tri    VN81113     None
# 26     0.593530    0.012181    Bac Lieu      TP. Bạc Liêu    VN82101     None
# ..          ...         ...         ...               ...        ...      ...
# 674    1.127616    0.020695    Vinh Loi    Huyện Vĩnh Lợi    VN82105     None
# 675    0.385001    0.004032   Vinh Long     TP. Vĩnh Long    VN80901     None
# 677    0.946339    0.025393  Vinh Thanh  Huyện Vĩnh Thạnh    VN81511     None
# 678    0.901804    0.030805  Vinh Thuan  Huyện Vĩnh Thuận    VN81319     None
# 685    0.953600    0.025231   Vung Liem   Huyện Vũng Liêm    VN80913     None
#
#     ADM2ALT1EN ADM2ALT2EN ADM2ALT1VI ADM2ALT2VI       ADM1_EN      ADM1_VI  \
# 1         None       None       None       None    Kien Giang   Kiên Giang
# 6         None       None       None       None    Kien Giang   Kiên Giang
# 8         None       None       None       None      An Giang     An Giang
# 19        None       None       None       None       Ben Tre      Bến Tre
# 26        None       None       None       None      Bac Lieu     Bạc Liêu
# ..         ...        ...        ...        ...           ...          ...
# 674       None       None       None       None      Bac Lieu     Bạc Liêu
# 675       None       None       None       None     Vinh Long    Vĩnh Long
# 677       None       None       None       None  Can Tho city  TP. Cần Thơ
# 678       None       None       None       None    Kien Giang   Kiên Giang
# 685       None       None       None       None     Vinh Long    Vĩnh Long
#
#     ADM1_PCODE   ADM0_EN   ADM0_VI ADM0_PCODE        date     validOn validTo  \
# 1        VN813  Viet Nam  Việt Nam         VN  2019-10-01  2020-01-03    None
# 6        VN813  Viet Nam  Việt Nam         VN  2019-10-01  2020-01-03    None
# 8        VN805  Viet Nam  Việt Nam         VN  2019-10-01  2020-01-03    None
# 19       VN811  Viet Nam  Việt Nam         VN  2019-10-01  2020-01-03    None
# 26       VN821  Viet Nam  Việt Nam         VN  2019-10-01  2020-01-03    None
# ..         ...       ...       ...        ...         ...         ...     ...
# 674      VN821  Viet Nam  Việt Nam         VN  2019-10-01  2020-01-03    None
# 675      VN809  Viet Nam  Việt Nam         VN  2019-10-01  2020-01-03    None
# 677      VN815  Viet Nam  Việt Nam         VN  2019-10-01  2020-01-03    None
# 678      VN813  Viet Nam  Việt Nam         VN  2019-10-01  2020-01-03    None
# 685      VN809  Viet Nam  Việt Nam         VN  2019-10-01  2020-01-03    None
#
#                                               geometry
# 1    POLYGON ((105.12050 9.85495, 105.12673 9.84550...
# 6    POLYGON ((105.03754 9.62409, 105.03753 9.62406...
# 8    POLYGON ((105.11716 10.95483, 105.11732 10.951...
# 19   POLYGON ((106.61821 10.16628, 106.62171 10.157...
# 26   POLYGON ((105.82112 9.30130, 105.82227 9.29527...
# ..                                                 ...
# 674  POLYGON ((105.59488 9.42122, 105.59681 9.42007...
# 675  POLYGON ((105.93992 10.27409, 105.94104 10.273...
# 677  POLYGON ((105.48278 10.30985, 105.48286 10.309...
# 678  POLYGON ((105.27414 9.68080, 105.27434 9.68035...
# 685  POLYGON ((106.19085 10.17549, 106.19469 10.172...
#
# [132 rows x 20 columns]

# %%
for _, r in mk_provinces.iterrows():
    # Without simplifying the representation of each borough,
    # the map might not be displayed
    sim_geo = gpd.GeoSeries(r['geometry']).simplify(tolerance=0.001)
    geo_j = sim_geo.to_json()
    geo_j = folium.GeoJson(data=geo_j,
                           style_function=lambda x: {'fillColor': 'orange'})
    folium.Popup(r['ADM1_EN']).add_to(geo_j)
    geo_j.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a35e06993178117b10e24efaabfb4f7e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a35e06993178117b10e24efaabfb4f7e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a35e06993178117b10e24efaabfb4f7e = L.map(
#                 &quot;map_a35e06993178117b10e24efaabfb4f7e&quot;,
#                 {
#                     center: [10.0, 105.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1927d6d98872c1ca8fbb00bf5dbacd28 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a35e06993178117b10e24efaabfb4f7e);
#
#
#         function geo_json_6c6af6268c66347a47f6c72ba791bfc6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;};
#             }
#         }
#
#         function geo_json_6c6af6268c66347a47f6c72ba791bfc6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6c6af6268c66347a47f6c72ba791bfc6 = L.geoJson(null, {
#                 onEachFeature: geo_json_6c6af6268c66347a47f6c72ba791bfc6_onEachFeature,
#
#                 style: geo_json_6c6af6268c66347a47f6c72ba791bfc6_styler,
#         });
#
#         function geo_json_6c6af6268c66347a47f6c72ba791bfc6_add (data) {
#             geo_json_6c6af6268c66347a47f6c72ba791bfc6
#                 .addData(data)
#                 .addTo(map_a35e06993178117b10e24efaabfb4f7e);
#         }
#             geo_json_6c6af6268c66347a47f6c72ba791bfc6_add({&quot;bbox&quot;: [104.77806862800009, 10.183523748000027, 105.57548204300008, 10.961223799000038], &quot;features&quot;: [{&quot;bbox&quot;: [104.77806862800009, 10.183523748000027, 105.57548204300008, 10.961223799000038], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[105.11715967500004, 10.954833844000063], [105.11736124800007, 10.948877496000023], [105.11520111900006, 10.940461933000051], [105.10109134400005, 10.92671481900004], [105.10051059800008, 10.92226967800002], [105.10783364000008, 10.917574820000027], [105.13187474100005, 10.921558262000076], [105.15605165100004, 10.92330215800007], [105.18118531900006, 10.911759337000035], [105.18739239300004, 10.91153524300006], [105.18869254800006, 10.891550297000038], [105.18777611100006, 10.873263003000034], [105.19360505300006, 10.866002380000054], [105.20351318400009, 10.858301334000032], [105.20808693400005, 10.852053363000039], [105.21898338200003, 10.834131378000052], [105.22916489800008, 10.805719389000046], [105.25914153700006, 10.80269794700007], [105.26093226600005, 10.790289352000059], [105.25809897400006, 10.782413423000037], [105.25938619400006, 10.774668588000054], [105.26156218500006, 10.77092951800006], [105.27347396100004, 10.764353594000056], [105.29523095300004, 10.763323094000043], [105.30040493400008, 10.761769289000028], [105.30322838100005, 10.759140325000033], [105.30407511400006, 10.754695254000069], [105.30172053900009, 10.748994541000059], [105.28267605500008, 10.73757874000006], [105.27708731600006, 10.732196948000023], [105.27561842900008, 10.726878613000054], [105.27854277800009, 10.723037760000068], [105.28715225700006, 10.718854867000061], [105.29695487400005, 10.716488637000054], [105.30550044300008, 10.716850563000037], [105.32528623500008, 10.722250702000053], [105.33567088700005, 10.722980146000054], [105.34176381300006, 10.721963324000058], [105.34856718800006, 10.717107362000036], [105.34817529600008, 10.702125429000034], [105.34204946500006, 10.673918159000038], [105.34290694100008, 10.637641608000024], [105.34943398900003, 10.617611546000035], [105.36842386100005, 10.576338354000029], [105.39165938900004, 10.569001439000033], [105.39734717000005, 10.565697896000074], [105.40953394200005, 10.553909539000074], [105.41693371400004, 10.550019489000022], [105.44465431400005, 10.55291943900005], [105.47986276000006, 10.535613463000061], [105.48613224300004, 10.541729407000048], [105.50320104300005, 10.546284728000046], [105.50988988500006, 10.545003420000057], [105.51244051200007, 10.547125459000029], [105.53090670600005, 10.53818367100007], [105.54856434400006, 10.523210109000047], [105.55677353500005, 10.510510060000058], [105.57073054800009, 10.478492775000063], [105.57548204300008, 10.448423707000075], [105.57412071000005, 10.429450820000056], [105.56475656900005, 10.429931810000028], [105.55482575000008, 10.434310119000031], [105.55126443900008, 10.430150038000022], [105.54855812900007, 10.429472375000046], [105.54938760600004, 10.424929275000068], [105.54652881600003, 10.421197967000069], [105.55203714000004, 10.419141284000034], [105.55244062500009, 10.416914508000048], [105.54513325900007, 10.412844154000027], [105.53927143600004, 10.413312878000056], [105.53598248100008, 10.40943678800005], [105.53170186200003, 10.407956217000049], [105.52949361000009, 1

# %%
# Adding centroid markers
# Getting centroid point and creating new col to add to database
database_gdf.to_crs('epsg:4326') #https://geopandas.org/en/stable/docs/reference/api/geopandas.GeoDataFrame.set_crs.html#geopandas.GeoDataFrame.set_crs
database_gdf['centroid'] = database_gdf.centroid
# Out:
# C:\Users\sy6sh\AppData\Local\Temp\ipykernel_12092\3191177276.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   database_gdf['centroid'] = database_gdf.centroid

# %%
# To make sure you can get all projects at the same location you need to cluster the markers
from folium.plugins import MarkerCluster

# %%
# Creating map with cluster

#(Source:https://deparkes.co.uk/2016/06/24/folium-marker-clusters/ )
# create a marker cluster called "Riceshrimp research cluster"
marker_cluster = MarkerCluster().add_to(map) #If I put a name for the MarkerCluster in the brackets it didnt work but once I removed it it was fine.
map
for _, r in database_gdf.iterrows():
    lat = r['centroid'].y
    lon = r['centroid'].x
    #folium.Marker(location=[lat, lon], popup= "Start Year: " + str(r['Start Year']) + "<br>" + "End Year: " + str(r['End Year']) + "<br>" + "Organisation: " + str(r['Organisation']) + "<br>" + "Type: " + str(r['Training workshop / Research']) + "<br>" + "Report: " + "<a>" + str(r['Source']) +"</a>",).add_to(map)
    # Setting up content of popup
    iframe = folium.IFrame("Project name / Report title: " + str(r['Project']) + "<br>" + "Start Year: " + str(r['Start Year']) + "<br>" + "End Year: " + str(r['End Year']) + "<br>" + "Organisation: " + str(r['Organisation']) + "<br>" + "Type: " + str(r['Training workshop / Research']) + "<br>" + "Report: " + "<a>" + str(r['Source']) +"</a>")
    #Initialise the popup using the iframe
    popup = folium.Popup(iframe, min_width=300, max_width=300)
    
    # Controling Folium marker colour by organisation: https://towardsdatascience.com/folium-mapping-displaying-markers-on-a-map-6bd56f3e3420
    org_colour = {'UNSW':'pink','USAID, Mekong ARCC, ADMI, VNRC':'red','ACIAR':'green'}

    try:
        icon_color = org_colour[r['Organisation']]
    except:
        #Catch nans
        icon_color = 'gray'

    #Add each row to map
    #folium.Marker(location=[lat, lon], popup=popup, icon =folium.Icon(color = icon_color, icon='')).add_to(map)
    # Instead adding clusters to map instead of individual points as above
    folium.Marker(location=[lat, lon], popup=popup, icon =folium.Icon(color = icon_color, icon='')).add_to(marker_cluster)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a35e06993178117b10e24efaabfb4f7e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a35e06993178117b10e24efaabfb4f7e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a35e06993178117b10e24efaabfb4f7e = L.map(
#                 &quot;map_a35e06993178117b10e24efaabfb4f7e&quot;,
#                 {
#                     center: [10.0, 105.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1927d6d98872c1ca8fbb00bf5dbacd28 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a35e06993178117b10e24efaabfb4f7e);
#
#
#         function geo_json_6c6af6268c66347a47f6c72ba791bfc6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;};
#             }
#         }
#
#         function geo_json_6c6af6268c66347a47f6c72ba791bfc6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6c6af6268c66347a47f6c72ba791bfc6 = L.geoJson(null, {
#                 onEachFeature: geo_json_6c6af6268c66347a47f6c72ba791bfc6_onEachFeature,
#
#                 style: geo_json_6c6af6268c66347a47f6c72ba791bfc6_styler,
#         });
#
#         function geo_json_6c6af6268c66347a47f6c72ba791bfc6_add (data) {
#             geo_json_6c6af6268c66347a47f6c72ba791bfc6
#                 .addData(data)
#                 .addTo(map_a35e06993178117b10e24efaabfb4f7e);
#         }
#             geo_json_6c6af6268c66347a47f6c72ba791bfc6_add({&quot;bbox&quot;: [104.77806862800009, 10.183523748000027, 105.57548204300008, 10.961223799000038], &quot;features&quot;: [{&quot;bbox&quot;: [104.77806862800009, 10.183523748000027, 105.57548204300008, 10.961223799000038], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[105.11715967500004, 10.954833844000063], [105.11736124800007, 10.948877496000023], [105.11520111900006, 10.940461933000051], [105.10109134400005, 10.92671481900004], [105.10051059800008, 10.92226967800002], [105.10783364000008, 10.917574820000027], [105.13187474100005, 10.921558262000076], [105.15605165100004, 10.92330215800007], [105.18118531900006, 10.911759337000035], [105.18739239300004, 10.91153524300006], [105.18869254800006, 10.891550297000038], [105.18777611100006, 10.873263003000034], [105.19360505300006, 10.866002380000054], [105.20351318400009, 10.858301334000032], [105.20808693400005, 10.852053363000039], [105.21898338200003, 10.834131378000052], [105.22916489800008, 10.805719389000046], [105.25914153700006, 10.80269794700007], [105.26093226600005, 10.790289352000059], [105.25809897400006, 10.782413423000037], [105.25938619400006, 10.774668588000054], [105.26156218500006, 10.77092951800006], [105.27347396100004, 10.764353594000056], [105.29523095300004, 10.763323094000043], [105.30040493400008, 10.761769289000028], [105.30322838100005, 10.759140325000033], [105.30407511400006, 10.754695254000069], [105.30172053900009, 10.748994541000059], [105.28267605500008, 10.73757874000006], [105.27708731600006, 10.732196948000023], [105.27561842900008, 10.726878613000054], [105.27854277800009, 10.723037760000068], [105.28715225700006, 10.718854867000061], [105.29695487400005, 10.716488637000054], [105.30550044300008, 10.716850563000037], [105.32528623500008, 10.722250702000053], [105.33567088700005, 10.722980146000054], [105.34176381300006, 10.721963324000058], [105.34856718800006, 10.717107362000036], [105.34817529600008, 10.702125429000034], [105.34204946500006, 10.673918159000038], [105.34290694100008, 10.637641608000024], [105.34943398900003, 10.617611546000035], [105.36842386100005, 10.576338354000029], [105.39165938900004, 10.569001439000033], [105.39734717000005, 10.565697896000074], [105.40953394200005, 10.553909539000074], [105.41693371400004, 10.550019489000022], [105.44465431400005, 10.55291943900005], [105.47986276000006, 10.535613463000061], [105.48613224300004, 10.541729407000048], [105.50320104300005, 10.546284728000046], [105.50988988500006, 10.545003420000057], [105.51244051200007, 10.547125459000029], [105.53090670600005, 10.53818367100007], [105.54856434400006, 10.523210109000047], [105.55677353500005, 10.510510060000058], [105.57073054800009, 10.478492775000063], [105.57548204300008, 10.448423707000075], [105.57412071000005, 10.429450820000056], [105.56475656900005, 10.429931810000028], [105.55482575000008, 10.434310119000031

# %% [markdown]
# # Improvements

# %% [markdown]
# Customise pop ups so that they have table of information and html links that are clickable. Try this: https://towardsdatascience.com/folium-map-how-to-create-a-table-style-pop-up-with-html-code-76903706b88a

# %% [markdown]
# https://www.kaggle.com/code/dabaker/fancy-folium/notebook

# %%
# Source above
def popup_html(row):
    i = row
    #print(i)
    report_proj_name = database_gdf['Project'].iloc[i]
    start_yr=database_gdf['Start Year'].iloc[i]
    end_yr = database_gdf['End Year'].iloc[i] 
    org_name =database_gdf['Organisation'].iloc[i] 
    typ_research = database_gdf['Training workshop / Research'].iloc[i]
    report = database_gdf['Source'].iloc[i]
    
    #print('<a href ="{}"></a>'.format(report))

    left_col_color = "#19a7bd"
    right_col_color = "#f2f0d3"
    
    html = """<!DOCTYPE html>
    <html>
    <head>
    <h4 style="margin-bottom:10"; width="200px">{}</h4>""".format(report_proj_name) + """
    </head>
        <table style="height: 126px; width: 350px;">
    <tbody>
    <tr>
    <td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Start Year</span></td>
    <td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(start_yr) + """
    </tr>
    <tr>
    <td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">End Year</span></td>
    <td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(end_yr) + """
    </tr>
    <tr>
    <td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Organisation Name</span></td>
    <td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(org_name) + """
    </tr>
    <tr>
    <td style="background-color: """+ left_col_color +""";"><span style="color: #ffffff;">Type of research</span></td>
    <td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(typ_research) + """
    </tr>
    <tr>
    <td style="background-color: """+ left_col_color +""";"> <span style="color: #ffffff;">URL</span></td>
    <td style="width: 150px;background-color: """+ right_col_color +""";"><a href ="{}">Report PDF</a>""".format(report)+"""</td>""".format(report)+"""
    </tr>
    </tbody>
    </table>
    </html>
    """
    # the hyperlink was created using examples from here: https://www.geeksforgeeks.org/how-to-create-a-table-with-clickable-hyperlink-to-a-local-file-in-pandas/
    # Instead of putting two {} {}: I only put one to fix this error IndexError: Replacement index 1 out of range for positional args tuple https://pytutorial.com/indexerror-replacement-index-1-index-format/
    # Understanding that you need a text between <a> and </a> to display the hyperlink - https://jsfiddle.net/BF729/. However since it always opens a pdf to file then I put Report Pdf instead. 
    return html

# %%
import branca

# %%
# Creating map with cluster
#(Source:https://deparkes.co.uk/2016/06/24/folium-marker-clusters/ )
marker_cluster = MarkerCluster().add_to(map) #If I put a name for the MarkerCluster in the brackets it didnt work but once I removed it it was fine.
map
# Now adding the pop up table code (Source:https://towardsdatascience.com/folium-map-how-to-create-a-table-style-pop-up-with-html-code-76903706b88a )
for _, r in database_gdf.iterrows():
    lat = r['centroid'].y
    lon = r['centroid'].x
    html = popup_html(_) #where _ is the iterations or row number I believe since it is a variable
    iframe = branca.element.IFrame(html=html, width = 510, height = 280)
    popup = folium.Popup(folium.Html(html,script=True), min_width=300, max_width=500)
    
    # Controling Folium marker colour by organisation: https://towardsdatascience.com/folium-mapping-displaying-markers-on-a-map-6bd56f3e3420
    org_colour = {'UNSW':'pink','USAID, Mekong ARCC, ADMI, VNRC':'red','ACIAR':'green'}

    try:
        icon_color = org_colour[r['Organisation']]
    except:
        #Catch nans
        icon_color = 'gray'

    #Add each row to map
    #folium.Marker(location=[lat, lon], popup=popup, icon =folium.Icon(color = icon_color, icon='')).add_to(map)
    # Instead adding clusters to map instead of individual points as above
    folium.Marker(location=[lat, lon], popup=popup, icon =folium.Icon(color = icon_color, icon='')).add_to(marker_cluster)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a35e06993178117b10e24efaabfb4f7e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a35e06993178117b10e24efaabfb4f7e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a35e06993178117b10e24efaabfb4f7e = L.map(
#                 &quot;map_a35e06993178117b10e24efaabfb4f7e&quot;,
#                 {
#                     center: [10.0, 105.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1927d6d98872c1ca8fbb00bf5dbacd28 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a35e06993178117b10e24efaabfb4f7e);
#
#
#         function geo_json_6c6af6268c66347a47f6c72ba791bfc6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;};
#             }
#         }
#
#         function geo_json_6c6af6268c66347a47f6c72ba791bfc6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6c6af6268c66347a47f6c72ba791bfc6 = L.geoJson(null, {
#                 onEachFeature: geo_json_6c6af6268c66347a47f6c72ba791bfc6_onEachFeature,
#
#                 style: geo_json_6c6af6268c66347a47f6c72ba791bfc6_styler,
#         });
#
#         function geo_json_6c6af6268c66347a47f6c72ba791bfc6_add (data) {
#             geo_json_6c6af6268c66347a47f6c72ba791bfc6
#                 .addData(data)
#                 .addTo(map_a35e06993178117b10e24efaabfb4f7e);
#         }
#             geo_json_6c6af6268c66347a47f6c72ba791bfc6_add({&quot;bbox&quot;: [104.77806862800009, 10.183523748000027, 105.57548204300008, 10.961223799000038], &quot;features&quot;: [{&quot;bbox&quot;: [104.77806862800009, 10.183523748000027, 105.57548204300008, 10.961223799000038], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[105.11715967500004, 10.954833844000063], [105.11736124800007, 10.948877496000023], [105.11520111900006, 10.940461933000051], [105.10109134400005, 10.92671481900004], [105.10051059800008, 10.92226967800002], [105.10783364000008, 10.917574820000027], [105.13187474100005, 10.921558262000076], [105.15605165100004, 10.92330215800007], [105.18118531900006, 10.911759337000035], [105.18739239300004, 10.91153524300006], [105.18869254800006, 10.891550297000038], [105.18777611100006, 10.873263003000034], [105.19360505300006, 10.866002380000054], [105.20351318400009, 10.858301334000032], [105.20808693400005, 10.852053363000039], [105.21898338200003, 10.834131378000052], [105.22916489800008, 10.805719389000046], [105.25914153700006, 10.80269794700007], [105.26093226600005, 10.790289352000059], [105.25809897400006, 10.782413423000037], [105.25938619400006, 10.774668588000054], [105.26156218500006, 10.77092951800006], [105.27347396100004, 10.764353594000056], [105.29523095300004, 10.763323094000043], [105.30040493400008, 10.761769289000028], [105.30322838100005, 10.759140325000033], [105.30407511400006, 10.754695254000069], [105.30172053900009, 10.748994541000059], [105.28267605500008, 10.73757874000006], [105.27708731600006, 10.732196948000023], [105.27561842900008, 10.726878613000054], [105.27854277800009, 10.723037760000068], [105.28715225700006, 10.718854867000061], [105.29695487400005, 10.716488637000054], [105.30550044300008, 10.716850563000037], [105.32528623500008, 10.722250702000053], [105.33567088700005, 10.722980146000054], [105.34176381300006, 10.721963324000058], [105.34856718800006, 10.717107362000036], [105.34817529600008, 10.702125429000034], [105.34204946500006, 10.673918159000038], [105.34290694100008, 10.637641608000024], [105.34943398900003, 10.617611546000035], [105.36842386100005, 10.576338354000029], [105.39165938900004, 10.569001439000033], [105.39734717000005, 10.565697896000074], [105.40953394200005, 10.553909539000074], [105.41693371400004, 10.550019489000022], [105.44465431400005, 10.55291943900005], [105.47986276000006, 10.535613463000061], [105.48613224300004, 10.541729407000048], [105.50320104300005, 10.546284728000046], [105.50988988500006, 10.545003420000057], [105.51244051200007, 10.547125459000029], [105.53090670600005, 10.53818367100007], [105.54856434400006, 10.523210109000047], [105.55677353500005, 10.510510060000058], [105.57073054800009, 10.478492775000063], [105.57548204300008, 10.448423707000075], [105.57412071000005, 10.429450820000056], [105.56475656900005, 10.429931810000028], [105.55482575000008, 10.434310119000031
